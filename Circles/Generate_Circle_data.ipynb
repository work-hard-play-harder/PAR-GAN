# %%
import numpy as np
from sklearn.mixture import GaussianMixture
import pickle
from sklearn import datasets
from matplotlib import pyplot as plt
import matplotlib.cm as cm

# %% [markdown]
# # Generate

# %%
n_samples = 10000
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,
                                      noise=.05)

# %%
noisy_circles[0]
# Out:
# array([[-0.14123689, -0.9274996 ],
#        [-0.52481902,  0.81863754],
#        [-0.99282919, -0.0857416 ],
#        ...,
#        [ 0.04935669, -0.50928588],
#        [ 0.52290649,  0.06062043],
#        [-0.34694683,  0.34859745]])

# %%
noisy_circles[1]
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
figure, axes = plt.subplots(nrows=1, ncols=1, figsize=(4.5, 4.5))
axes.set_aspect('equal')
axes.axis('on')
axes.set_title('GMM')

x = noisy_circles[0]
targets = noisy_circles[1]

axes.scatter(x[:, 0],
             x[:, 1],
             marker='.',
             c=cm.Set1(targets.astype(float) / 2.0 / 2.0),
             alpha=0.3)
plt.tight_layout()
#     plt.savefig(save_path, transparent=True, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Save

# %%
with open('noisy_circles_data.pkl', 'wb') as f:
    pickle.dump(noisy_circles, f)
